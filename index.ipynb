# %% [markdown]
# # Project: Regression Modeling with the Boston Housing Dataset
#
# ## Introduction
#
# In this lab, you'll apply the regression analysis and diagnostics techniques covered in this section to the "Boston Housing" dataset. You performed a detailed EDA for this dataset earlier on, and hopefully, you more or less recall how this data is structured! In this lab, you'll use some of the features in this dataset to create a linear model to predict the house price!
#
# ## Objectives
# You will be able to:
# * Perform a linear regression using statsmodels
# * Determine if a particular set of data exhibits the assumptions of linear regression
# * Evaluate a linear regression model by using statistical performance metrics pertaining to overall model and specific parameters
# * Use the coefficient of determination to determine model performance
# * Interpret the parameters of a simple linear regression model in relation to what they signify for specific data
#
#
# ## Let's get started
#
# ### Import necessary libraries and load 'BostonHousing.csv' as a pandas dataframe

# %%
# Your code here
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
import scipy.stats as stats
plt.style.use('ggplot')

data = pd.read_csv('BostonHousing.csv', index_col=0)
# Out:
#            zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# crim
# 0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#               b  lstat  medv
# crim
# 0.00632  396.90   4.98  24.0
# 0.02731  396.90   9.14  21.6
# 0.02729  392.83   4.03  34.7
# 0.03237  394.63   2.94  33.4
# 0.06905  396.90   5.33  36.2

# %% [markdown]
# The columns in the Boston housing data represent the dependent and independent variables. The dependent variable here is the median house value `MEDV`. The description of the other variables is available on [KAGGLE](https://www.kaggle.com/c/boston-housing).
#
# ### Inspect the columns of the dataset and comment on type of variables present

# %%
# Your code here
data = data.reset_index()
data.head()
# data.isna().sum()
# data.describe()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# Record your observations here 
# The data contain no null values. 
# The dataset consists of categorical and continuous variables.

# %% [markdown]
# ### Create histograms for all variables in the dataset and comment on their shape (uniform or not?)

# %%
# Your code here 
# fig, axs = plt.subplots(2, 3, sharey=True, figsize=(18, 6))
for column in data:
    data[column].plot.hist(density=True, label = column+' histogram')
    data[column].plot.kde(label =column+' kde')
    plt.legend()
    plt.show()

# %%
# You observations here 
# Crime rate is skewed left.
# The proportion of residential land zoned for lots over 25,000 sq.ft. (zn) is skewed left.
# The proportion of non-retail business acres per town (indus) is not normally distributed.
# The presence of the Charles River (chas) is skewed right.
# The nitrogen oxides concentration (parts per 10 million) (nox) is skewed left.
# The average number of rooms per dwelling (rm) is normally distributed with a slight skew left.

#...Most variables are skewed or exhibit outliers.

# %% [markdown]
# Based on this, we preselected some features  for you which appear to be more 'normal' than others.
# ### Create a new dataset with `['crim', 'dis', 'rm', 'zn', 'age', 'medv']`

# %%
# Your code here
data = data[['crim', 'dis', 'rm', 'zn', 'age', 'medv']].copy()
data.head()
# Out:
#       crim     dis     rm    zn   age  medv
# 0  0.00632  4.0900  6.575  18.0  65.2  24.0
# 1  0.02731  4.9671  6.421   0.0  78.9  21.6
# 2  0.02729  4.9671  7.185   0.0  61.1  34.7
# 3  0.03237  6.0622  6.998   0.0  45.8  33.4
# 4  0.06905  6.0622  7.147   0.0  54.2  36.2

# %% [markdown]
# ### Check the linearity assumption for all chosen features with target variable using scatter plots

# %%
# Your code here 
fig, axs = plt.subplots(1, 6, sharey=True, figsize=(18,3))
for idx, channel in enumerate(['crim', 'dis', 'rm', 'zn', 'age', 'medv']):
    data.plot(kind='scatter', x=channel, y='medv', ax=axs[idx], label=channel)
plt.legend()
plt.show()

# %%
# Your observations here 
# We see a possible positive correlation between rm and medv.
# We see a posible negative correlation between crim and medv.
# All plots exhibit outliers.

# %% [markdown]
# Clearly, your data needs a lot of preprocessing to improve the results. This key behind a Kaggle competition is to process the data in such a way that you can identify the relationships and make predictions in the best possible way. For now, we'll use the dataset untouched and just move on with the regression. The assumptions are not _exactly_ all fulfilled, but they still hold to a level that we can move on.
#
# ### Let's do Regression
#
# Now, let's perform a number of simple regression experiments between the chosen independent variables and the dependent variable (price). You'll do this in a loop and in every iteration, you should pick one of the independent variables. Perform the following steps:
#
# * Run a simple OLS regression between independent and dependent variables
# * Plot a regression line on the scatter plots
# * Plot the residuals using `sm.graphics.plot_regress_exog()`
# * Plot a Q-Q plot for regression residuals normality test
# * Store following values in array for each iteration:
#     * Independent Variable
#     * r_squared'
#     * intercept'
#     * 'slope'
#     * 'p-value'
#     * 'normality (JB)'
# * Comment on each output

# %%
# import libraries
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
column_names =  ['crim', 'dis', 'rm', 'zn', 'age', 'medv']
results = [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)' ]]
for index, column_name in enumerate(column_names):
    
    # Create section break
    print (f"Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~{column_name}")
    print ("-------------------------------------------------------------------------------------")
    
    # build the formula 
    f = f'medv~{column_name}'

    # create a fitted model in one line
    model = smf.ols(formula=f, data=data).fit()
    model.summary()

    # create a DataFrame with the minimum and maximum values
    column_name_df = pd.DataFrame(
        {column_name: [data[column_name].min(),
                      data[column_name].max()]}
    )

    # make predictions for those x values and store them
    pred = model.predict(column_name_df)
    pred

    # first, plot the observed data and the least squares line
    plt.plot(column_name_df, pred, c="lime")
    plt.scatter(data[column_name], data.medv)

    fig = plt.figure(figsize=(15,8))
    fig = sm.graphics.plot_regress_exog(model, column_name, fig=fig)
    fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True,   )
    plt.show()
    
    results.append([column_name, model.rsquared, model.params[0], model.params[1], model.pvalues[1], sms.jarque_bera(model.resid)[0] ])
# Out:
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~crim
# -------------------------------------------------------------------------------------
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~dis
# -------------------------------------------------------------------------------------
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~rm
# -------------------------------------------------------------------------------------
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~zn
# -------------------------------------------------------------------------------------
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~age
# -------------------------------------------------------------------------------------
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~medv
# -------------------------------------------------------------------------------------

# %%
pd.DataFrame(results)
# Out:
#          0          1            2         3            4               5
# 0  ind_var  r_squared    intercept     slope      p-value  normality (JB)
# 1     crim    0.15078      24.0331  -0.41519  1.17399e-19         295.404
# 2      dis  0.0624644      18.3901   1.09161  1.20661e-08         305.104
# 3       rm   0.483525     -34.6706   9.10211  2.48723e-74         612.449
# 4       zn   0.129921      20.9176   0.14214  5.71358e-17         262.387
# 5      age   0.142095      30.9787 -0.123163  1.56998e-18         456.983
# 6     medv          1 -8.10463e-15         1            0         288.493

# %% [markdown]
# ## CRIM
#
# The R-squared value of 0.151 tells us that only 15.1% of the variance in median value can be predicted by the crime rate
#
# The relationship between criminal rates shows heteroscedasticity and numerous outliers.
# We cannot assume normality.

# %% [markdown]
# ## DIS
# The R-squared value of 0.062 tells us that only 6.2% of the variance in median value can be predicted by the weighted mean of distances to five Boston employment centres.
#
# Our plots show clear heteroscedasticity and indicate that we cannot assume normality.

# %% [markdown]
# ## AGE
# The R-squared value of 0.142 tells us that only 14.2% of the variance in median value can be predicted by the proportion of owner-occupied units built prior to 1940.
#
# Our plots show clear heteroscedasticity and indicate that we cannot assume normality.

# %% [markdown]
# ## RM
# The R-squared value of 0.484 tells us that 48.4% of the variance in median value can be predicted by the number of rooms.
#
# Our plots show clear heteroscedasticity and indicate that we cannot assume normality.

# %% [markdown]
# Clearly, the results are not very reliable. The best R-Squared is witnessed with `rm`, so in this analysis, this is our best predictor.
#
# ### How can you improve these results?
# 1. Preprocessing
#
# This is where the preprocessing of data comes in. Dealing with outliers, normalizing data, scaling values etc. can help regression analysis get more meaningful results from the given data.
#
# 2. Advanced Analytical Methods
#
# Simple regression is a very basic analysis technique and trying to fit a straight line solution to complex analytical questions may prove to be very inefficient. Later on, you'll explore multiple regression where you can use multiple features **at once** to define a relationship with the outcome. You'll also look at some preprocessing and data simplification techniques and revisit the Boston dataset with an improved toolkit.
#
# ## Level up - Optional
#
# Apply some data wrangling skills that you have learned in the previous section to pre-process the set of independent variables we chose above. You can start off with outliers and think of a way to deal with them. See how it affects the goodness of fit.
#
# ## Summary
#
# In this lab, you applied your skills learned so far on a new data set. You looked at the outcome of your analysis and realized that the data might need some preprocessing to see a clear improvement in the results. You'll pick this back up later on, after learning about more preprocessing techniques and advanced modeling techniques.
